# %%
# !conda create -y -n LoRA python=3.10 
# !conda run -n LoRA python --version

# %%
# !git clone https://github.com/facebookresearch/xformers.git
# %cd xformers
# !git submodule update --init --recursive

# %%
# !conda run -n LoRA --live-stream pip install torch==1.12.1+cu113 torchvision==0.13.1+cu113 --extra-index-url https://download.pytorch.org/whl/cu113

# %%
# !conda run -n LoRA --live-stream pip install -r requirements.txt
# !conda run -n LoRA --live-stream pip install wheel

# %%
# !conda run -n LoRA --live-stream python setup.py build
# !conda run -n LoRA --live-stream python setup.py bdist_wheel
